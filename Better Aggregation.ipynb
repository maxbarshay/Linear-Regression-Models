# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
iowa = pd.read_csv("/Users/mdbarshay/Desktop/401/Project 1/iowa-sample.csv")

# %%
iowacounties = pd.read_csv("/Users/mdbarshay/Desktop/401/Project 1/County_Population_in_Iowa_by_Year.csv")

# %%
iowacounties["County"] = iowacounties["County"].map(lambda x: x.split()[0])

# %%
iowacounties["Year"] = iowacounties["Year"].map(lambda x: x.split()[2])

# %%
iowacounties["Year"] = iowacounties["Year"].astype("int64")

# %%
# tot_iowa = pd.merge(iowa, iowacounties, on = "County", how = "left")

# %%
# tot_iowa["Gallons Sold Per Capita"] = tot_iowa["Volume Sold (Gallons)"] / tot_iowa["Pop"]

# %%
iowa["Date"] = iowa["Date"].astype("datetime64")

# %%
iowa["Year"] = pd.DatetimeIndex(iowa["Date"]).year

# %%
grouped_iowa = iowa.groupby(["County", "Year"]).sum()

# %%
grouped_iowa.sort_values(by = ["Year", "County"], inplace = True)

# %%
grouped_iowa
# Out:
#                  Store Number  Zip Code  County Number  Category  \
# County     Year
# Adair      2012          6922    100500              2   2103300
# Allamakee  2012          4005     52151              3   1012100
# Appanoose  2012          5046    105088              8   2063280
# Audubon    2012          3631     50025              5   1032200
# Benton     2012          4070     52208              6   1081390
# ...                       ...       ...            ...       ...
# Winnebago  2015         12988    151296            285   3155510
# Winneshiek 2015          3721     52101             96   1031080
# Woodbury   2015         31074    408685            776   8285320
# Worth      2015          3664     50459             98   1062300
# Sioux      2016          4255     51041             84   1071100
#
#                  Vendor Number  Item Number  Pack  Bottle Volume (ml)  \
# County     Year
# Adair      2012            405        75362    30                2125
# ...

# %%
iowacounties
# Out:
#        FIPS     County  Year  Population                   Primary Point
# 0     19169      Story  2011       91125  POINT (-93.4650448 42.0362415)
# 1     19061    Dubuque  2005       90926   POINT (-90.8824564 42.468832)
# 2     19085   Harrison  2000       15666  POINT (-95.8169209 41.6828528)
# 3     19007  Appanoose  1996       13723  POINT (-92.8686104 40.7431635)
# 4     19043    Clayton  2012       17946  POINT (-91.3414328 42.8447493)
# ...     ...        ...   ...         ...                             ...
# 2866  19097    Jackson  1996       20196  POINT (-90.5742294 42.1717426)
# 2867  19135     Monroe  2000        8016  POINT (-92.8689877 41.0297826)
# 2868  19179    Wapello  1991       35733  POINT (-92.4094499 41.0305845)
# 2869  19093        Ida  1996        8206  POINT (-95.5134962 42.3868747)
# 2870  19197     Wright  2017       12749  POINT (-93.7351465 42.7331189)
#
# [2871 rows x 5 columns]

# %%
tot_iowa = pd.merge(grouped_iowa, iowacounties, right_on = ["County", "Year"], left_index = True, how = "inner")

# %%
tot_iowa.set_index(["County", "Year"], inplace=True)

# %%
tot_iowa
# Out:
#                     State Bottle Cost  State Bottle Retail  Bottles Sold  \
# County        Year
# Adair         2012              15.20                22.80             7
# Allamakee     2012               4.28                 6.42             2
# Appanoose     2012              20.53                30.79             3
# Audubon       2012               6.87                10.81             1
# Benton        2012              13.33                19.99            12
# Buchanan      2012              12.50                18.75             2
# Butler        2012               6.63                 9.94            12
# Carroll       2012              16.43                24.64            12
# Cass          2012              21.79                32.69            12
# Cedar         2012               7.87                11.80             6
# Clarke        2012               7.53                11.30            12
# Clay          2012              23.39                35.08             5
# ...

# %%
tot_iowa["Volume Sold (Liters) Per Capita"] = tot_iowa["Volume Sold (Liters)"] / tot_iowa["Population"]
tot_iowa["Volume Sold (Gallons) Per Capita"] = tot_iowa["Volume Sold (Gallons)"] / tot_iowa["Population"]
tot_iowa["Sale (Dollars) Per Capita"] = tot_iowa["Sale (Dollars)"] / tot_iowa["Population"]
tot_iowa["Bottles Sold Per Capita"] = tot_iowa["Bottles Sold"] / tot_iowa["Population"]

# %%
tot_iowa.columns
# Out:
# Index(['Store Number', 'Zip Code', 'County Number', 'Category',
#        'Vendor Number', 'Item Number', 'Pack', 'Bottle Volume (ml)',
#        'State Bottle Cost', 'State Bottle Retail', 'Bottles Sold',
#        'Sale (Dollars)', 'Volume Sold (Liters)', 'Volume Sold (Gallons)',
#        'FIPS', 'Population', 'Primary Point',
#        'Volume Sold (Liters) Per Capita', 'Volume Sold (Gallons) Per Capita',
#        'Sale (Dollars) Per Capita', 'Bottles Sold Per Capita'],
#       dtype='object')

# %%
tot_iowa.drop(columns= ["Store Number", "Zip Code", "County Number", "Category", 'Vendor Number', 'Item Number', 'Pack', 'Bottle Volume (ml)', 'FIPS'], inplace = True)

# %%
tot_iowa
# Out:
#                  State Bottle Cost  State Bottle Retail  Bottles Sold  \
# County     Year
# Adair      2012              15.20                22.80             7
# Allamakee  2012               4.28                 6.42             2
# Appanoose  2012              20.53                30.79             3
# Audubon    2012               6.87                10.81             1
# Benton     2012              13.33                19.99            12
# ...                            ...                  ...           ...
# Winnebago  2015              36.28                54.43            18
# Winneshiek 2015               6.92                10.38             6
# Woodbury   2015              65.04                97.58            59
# Worth      2015              10.49                15.74             3
# Sioux      2016               6.00                 9.25             6
#
#                  Sale (Dollars)  Volume Sold (Liters)  Volume Sold (Gallons)  \
# County     Year
# ...

# %%
iowa
# Out:
#     Invoice/Item Number       Date  Store Number  \
# 0          S08096000008 2012-10-04          4641
# 1          S23102300041 2014-12-20          4346
# 2          S14410500035 2013-09-09          3628
# 3          S09427600021 2012-12-12          4708
# 4          S28446900114 2015-10-14          2594
# ..                  ...        ...           ...
# 995        S15723900021 2013-11-14          3997
# 996        S05143400018 2012-04-19          4483
# 997        S28018800016 2015-09-21          3926
# 998        S25060300052 2015-04-14          2353
# 999        S08928800075 2012-11-13          2448
#
#                                Store Name                  Address  \
# 0              Kum & Go #573 / SE 14th DM          5830 SE 14th ST
# 1                          Roy's Foodland             105 PEARL ST
# 2            Wal-Mart 1528 / Cedar Rapids  2645 BLAIRS FERRY RD NE
# 3    No Frills Supermarkets #803 / Glenwo             423 SHARP ST
# ...
