# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
from bs4 import BeautifulSoup
import requests
import re

url = "https://www.iowa-demographics.com/zip_codes_by_population"
myRequest = requests.get(url)
soup = BeautifulSoup(myRequest.text,"html.parser")

zipPops = {}

# for code in soup.find_all('a'):
#     text = code.text
#     if text[0].isdigit():
#         print(text)

res = []

for code in soup.find_all('tr'):

    inner = code.find_all('td')

    if len(inner) == 0:
        continue
    else:
        for item in inner:
            item = str(item).split()
            res.append(item)
            

            # print(item)
        
res = res[:-1]
# print(res)

for i in range(0, len(res), 3):

    val = res[i][-3]

    #print(val)
    if val == "TIE":
        #print("do stuff")

        and_count = 0
        rel = res[i+1]

        to_add = []

        for j in range(len(rel)):


            if re.search(r'f=\"(\d+)', rel[j]) is not None:

                to_add.append(re.search(r'f=\"(\d+)', rel[j]).group(1))

        popspot = res[i+2][1]
        pop = re.search(r"\d+,?\d+", popspot).group()

        for zipcode in to_add:

            zipPops[int(zipcode)] = pop


    else:
        
    # if i % 3 == 2:
        codespot = res[i+1][2]
        code = re.search(r"\d+", codespot).group()
        popspot = res[i+2][1]
        pop = re.search(r"\d+,?\d+", popspot).group()
        zipPops[int(code)] = pop



#

# print(soup)

# %%
len(zipPops)
# Out:
# 936

# %%
zipcode_data = pd.Series(zipPops).to_frame().reset_index()

# %%
zipcode_data = zipcode_data.rename(columns={"index": "Zip Code", 0: "Population"})

# %%
zipcode_data
# Out:
#      Zip Code Population
# 0       50613     44,154
# 1       52001     43,502
# 2       52402     41,407
# 3       52302     40,340
# 4       52404     39,284
# ..        ...        ...
# 931     50101         29
# 932     50033         29
# 933     51341         25
# 934     50227         22
# 935     50127         17
#
# [936 rows x 2 columns]

# %%
iowa = pd.read_csv("/Users/mdbarshay/Desktop/401/Project 1/iowa-sample.csv")

# %%
iowa["Date"] = iowa["Date"].astype("datetime64")

# %%
merged_iowa = pd.merge(iowa, zipcode_data, on = "Zip Code", how = "left")

# %%
merged_iowa["Population"] = merged_iowa["Population"].str.replace(",", "").astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-a7a7859617f5> in <module>
# ----> 1 merged_iowa["Population"] = merged_iowa["Population"].str.replace(",", "").astype(float)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# --> 175         accessor_obj = self._accessor(obj)
#     176         # Replace the property with the accessor object. Inspired by:
#     177         # http://www.pydanny.com/cached-property.html
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/strings.py in __init__(self, data)
#    1915
#    1916     def __init__(self, data):
# -> 1917         self._inferred_dtype = self._validate(data)
#    1918         self._is_categorical = is_categorical_dtype(data)
#    1919
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/strings.py in _validate(data)
#    1965
#    1966         if inferred_dtype not in allowed_types:
# -> 1967             raise AttributeError("Can only use .str accessor with string " "values!")
#    1968         return inferred_dtype
#    1969
#
# AttributeError: Can only use .str accessor with string values!

# %%
iowa
# Out:
#     Invoice/Item Number       Date  Store Number  \
# 0          S08096000008 2012-10-04          4641
# 1          S23102300041 2014-12-20          4346
# 2          S14410500035 2013-09-09          3628
# 3          S09427600021 2012-12-12          4708
# 4          S28446900114 2015-10-14          2594
# ..                  ...        ...           ...
# 995        S15723900021 2013-11-14          3997
# 996        S05143400018 2012-04-19          4483
# 997        S28018800016 2015-09-21          3926
# 998        S25060300052 2015-04-14          2353
# 999        S08928800075 2012-11-13          2448
#
#                                Store Name                  Address  \
# 0              Kum & Go #573 / SE 14th DM          5830 SE 14th ST
# 1                          Roy's Foodland             105 PEARL ST
# 2            Wal-Mart 1528 / Cedar Rapids  2645 BLAIRS FERRY RD NE
# 3    No Frills Supermarkets #803 / Glenwo             423 SHARP ST
# 4          Hy-Vee Food Store / Sioux City       4500 SERGEANT ROAD
# ..                                    ...                      ...
# 995               Wal-Mart 4606 / Osceola          2400 COLLEGE DR
# 996                                 Sauce            108 E COLLEGE
# 997           Liquor Downtown / Iowa City         315 S GILBERT ST
# 998                   Cresco Liquor Store           708 2ND AVE SE
# 999                       Bottle Boutique            705 E. SECOND
#
#              City  Zip Code                         Store Location  \
# 0      DES MOINES     50315                                    NaN
# 1      SHELLSBURG     52332           POINT (-91.869285 42.094155)
# 2    CEDAR RAPIDS     52402           POINT (-91.680734 42.034748)
# 3        GLENWOOD     51534            POINT (-95.742987 41.04635)
# 4      SIOUX CITY     51106           POINT (-96.346969 42.447396)
# ..            ...       ...                                    ...
# 995       OSCEOLA     50213  POINT (-93.800214 41.024891000000004)
# 996     IOWA CITY     52240           POINT (-91.533522 41.658979)
# 997     IOWA CITY     52240           POINT (-91.530181 41.657654)
# 998        CRESCO     52136           POINT (-92.106529 43.371131)
# 999     INDIANOLA     50125   POINT (-93.55261600000001 41.358176)
#
#      County Number    County  Category                       Category Name  \
# 0               77      Polk   1022100                             TEQUILA
# 1                6    Benton   1012100                   CANADIAN WHISKIES
# 2               57      Linn   1062300                        FLAVORED RUM
# 3               65     Mills   1011100                    BLENDED WHISKIES
# 4               97  Woodbury   1012100                   CANADIAN WHISKIES
# ..             ...       ...       ...                                 ...
# 995             20    Clarke   1011500               STRAIGHT RYE WHISKIES
# 996             52   Johnson   1081390                   IMPORTED SCHNAPPS
# 997             52   Johnson   1011200           STRAIGHT BOURBON WHISKIES
# 998             45    Howard   1081240               GREEN CREME DE MENTHE
# 999             91    Warren   1082900  MISC. IMPORTED CORDIALS & LIQUEURS
#
#      Vendor Number                       Vendor Name  Item Number  \
# 0              395                           Proximo        89191
# 1              115  Constellation Wine Company, Inc.        11774
# 2              260                   Diageo Americas        43410
# 3               65                   Jim Beam Brands        24458
# 4              115  Constellation Wine Company, Inc.        10550
# ..             ...                               ...          ...
# 995            255               Wilson Daniels Ltd.        27102
# 996            421                 Sazerac Co., Inc.        69667
# 997             65                   Jim Beam Brands        27544
# 998            434                    Luxco-St Louis        79336
# 999            192        Sidney Frank Importing Co.        65257
#
#                                Item Description  Pack  Bottle Volume (ml)  \
# 0    Jose Cuervo Especial Reposado Tequila Mini    12                 500
# 1                                  Black Velvet    24                 375
# 2             Captain Morgan Parrot Bay Coconut    12                 750
# 3                         Kessler Blend Whiskey     6                1750
# 4                  Black Velvet Toasted Caramel    12                 750
# ..                                          ...   ...                 ...
# 995                               Templeton Rye     6                 750
# 996                  Dr. Mcgillicuddy's Vanilla    12                1000
# 997                        Red Stag By Jim Beam    12                 750
# 998             Paramount Creme De Menthe/green    12                 750
# 999                        Jagermeister Liqueur    12                1000
#
#      State Bottle Cost  State Bottle Retail  Bottles Sold  Sale (Dollars)  \
# 0                11.50                17.25             1           17.25
# 1                 3.07                 4.61             6           27.66
# 2                 7.49                11.23            12          134.76
# 3                11.01                16.52            30          495.60
# 4                 6.75                10.13            12          121.56
# ..                 ...                  ...           ...             ...
# 995              18.09                27.14             6          162.84
# 996              11.00                16.50            12          198.00
# 997              10.49                15.74            12          188.88
# 998               4.75                 7.13             2           14.26
# 999              15.53                23.30             2           46.60
#
#      Volume Sold (Liters)  Volume Sold (Gallons)
# 0                    0.50                   0.13
# 1                    2.25                   0.59
# 2                    9.00                   2.38
# 3                   52.50                  13.87
# 4                    9.00                   2.38
# ..                    ...                    ...
# 995                  4.50                   1.19
# 996                 12.00                   3.17
# 997                  9.00                   2.38
# 998                  1.50                   0.40
# 999                  2.00                   0.53
#
# [1000 rows x 24 columns]

# %%
comb_iowa = iowa.groupby(["Zip Code", "Date"])[["State Bottle Cost", "State Bottle Retail", "Volume Sold (Liters)"]].sum()

# %%
comb_iowa

# %%
pd.merge(comb_iowa, zipcode_data, on = "Zip Code", left_index = True)

# %%
final_simple = merged_iowa.groupby(["Zip Code", "Date", "Population","State Bottle Cost", "State Bottle Retail"])[["Volume Sold (Liters)"]].sum()

# %%
final_simple
# Out:
#                                                                       Volume Sold (Liters)
# Zip Code Date       Population State Bottle Cost State Bottle Retail
# 50003    2013-08-27 7118.0     27.00             40.50                                0.75
# 50009    2012-02-02 19559.0    21.21             31.81                                0.80
#          2012-07-12 19559.0    10.14             15.58                                2.25
#          2013-03-07 19559.0    9.97              14.96                                9.00
#          2013-12-30 19559.0    6.83              10.24                                0.50
# ...                                                                                    ...
# 52807    2015-02-04 15638.0    5.23              7.85                                 1.00
#                                15.82             23.73                               31.50
#          2015-05-13 15638.0    26.49             39.74                                1.75
#          2015-08-12 15638.0    4.55              6.83                                 6.00
#          2015-11-11 15638.0    7.28              10.92                               48.00
#
# [992 rows x 1 columns]

# %%
final_simple.reset_index()
# Out:
#      Zip Code       Date  Population  State Bottle Cost  State Bottle Retail  \
# 0       50003 2013-08-27      7118.0              27.00                40.50
# 1       50009 2012-02-02     19559.0              21.21                31.81
# 2       50009 2012-07-12     19559.0              10.14                15.58
# 3       50009 2013-03-07     19559.0               9.97                14.96
# 4       50009 2013-12-30     19559.0               6.83                10.24
# ..        ...        ...         ...                ...                  ...
# 987     52807 2015-02-04     15638.0               5.23                 7.85
# 988     52807 2015-02-04     15638.0              15.82                23.73
# 989     52807 2015-05-13     15638.0              26.49                39.74
# 990     52807 2015-08-12     15638.0               4.55                 6.83
# 991     52807 2015-11-11     15638.0               7.28                10.92
#
#      Volume Sold (Liters)
# 0                    0.75
# 1                    0.80
# 2                    2.25
# 3                    9.00
# 4                    0.50
# ..                    ...
# 987                  1.00
# 988                 31.50
# 989                  1.75
# 990                  6.00
# 991                 48.00
#
# [992 rows x 6 columns]
